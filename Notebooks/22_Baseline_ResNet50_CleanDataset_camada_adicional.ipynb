# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Arquivos já estão divididos em treino, validação e teste.

# %%
# Referência Raquel
# src_path1 = '/content/gdrive/MyDrive/TrabalhoFinal_CleanDataset'
# train_path = os.path.join(src_path1, 'train_v2')
# train_path_emp = os.path.join(train_path, 'empresas')
# train_path_Nemp = os.path.join(train_path, 'nao_empresas')

# #src_path = '/content/gdrive/MyDrive/619_ProjetoFinal/Dados_ProjetoFinal/split_train_val_test'
# src_path = '/content/gdrive/MyDrive/Dados_ProjetoFinal_MDC010-INF019/split_train_val_test'
# val_path = os.path.join(src_path, 'val')
# test_path = os.path.join(src_path, 'test')

# val_path_emp = os.path.join(val_path, 'imagens_empresas')
# val_path_Nemp = os.path.join(val_path, 'imagens_nao_empresas')

# test_path_emp = os.path.join(test_path, 'imagens_empresas')
# test_path_Nemp = os.path.join(test_path, 'imagens_nao_empresas')

# %%
# Referência Igor
src_path = '/content/gdrive/MyDrive/619_ProjetoFinal/Dados_ProjetoFinal/split_train_val_test'
#src_path = '/content/gdrive/MyDrive/Dados_ProjetoFinal_MDC010-INF019/split_train_val_test'
train_path = os.path.join(src_path, 'train_v2')
val_path = os.path.join(src_path, 'val')
test_path = os.path.join(src_path, 'test')

train_path_emp = os.path.join(train_path, 'imagens_empresas')
train_path_Nemp = os.path.join(train_path, 'imagens_nao_empresas')

val_path_emp = os.path.join(val_path, 'imagens_empresas')
val_path_Nemp = os.path.join(val_path, 'imagens_nao_empresas')

test_path_emp = os.path.join(test_path, 'imagens_empresas')
test_path_Nemp = os.path.join(test_path, 'imagens_nao_empresas')

# %%
print('Número de imagens de empresas (treinamento):', len(os.listdir(train_path_emp)))
print('Número de imagens de não empresas (treinamento):', len(os.listdir(train_path_Nemp)))
print('Número de imagens de empresas (validacao):', len(os.listdir(val_path_emp)))
print('Número de imagens de não empresas (validacao):', len(os.listdir(val_path_Nemp)))
print('Número de imagens de empresas (teste):', len(os.listdir(test_path_emp)))
print('Número de imagens de não empresas (teste):', len(os.listdir(test_path_Nemp)))
# Out:
# Número de imagens de empresas (treinamento): 2689
# Número de imagens de não empresas (treinamento): 3859
# Número de imagens de empresas (validacao): 909
# Número de imagens de não empresas (validacao): 1291
# Número de imagens de empresas (teste): 910
# Número de imagens de não empresas (teste): 1292

# %% [markdown]
# #### Imprimindo algumas imagens usadas no treino:

# %%
numeroFiguras = 4

arrImagEmp = os.listdir(train_path_emp)
arrImagEmp = random.sample(arrImagEmp, numeroFiguras)
print(arrImagEmp)

arrImagNEmp = os.listdir(train_path_Nemp)
arrImagNEmp = random.sample(arrImagNEmp, numeroFiguras)
print(arrImagNEmp)
# Out:
# ['3820.jpg', '3635.jpg', '2860.jpg', '6241.jpg']
# ['7566.jpg', '6971.jpg', '8176.jpg', '7028.jpg']

# %%
fig = plt.figure(figsize=(10,5))

print("Imagens de empresas:")
for i in range(4):
    # Imagens de empresas:
    plt.subplot(240 + 1 + i)
    img = plt.imread(os.path.join(train_path_emp,arrImagEmp[i]))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
# Out:
# Imagens de empresas:

# %%
fig = plt.figure(figsize=(10,5))

print("Imagens de não empresas:")
for i in range(4):
    # Imagens de não empresas:
    z = i + 4
    plt.subplot(240 + 1 + z)
    img = plt.imread(os.path.join(train_path_Nemp,arrImagNEmp[i]))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
# Out:
# Imagens de não empresas:

# %% [markdown]
# ### Gerando dados de treino, validação e test.

# %%
import tensorflow as tf
from PIL import Image
from sklearn.utils.class_weight import compute_class_weight
from keras.preprocessing.image import ImageDataGenerator

#Definindo funções úteis para fazer os plots das imagens:
def plotImages(imgList, n_row=1, n_col=1):
    _, axs = plt.subplots(n_row, n_col, figsize=(25,5))
    axs = axs.flatten()
    for img, ax in zip(imgList, axs):
        ax.imshow(np.uint8(img), interpolation='nearest')
    plt.show()

# %% [markdown]
# #### Dados com aumentação.

# %% [markdown]
# ##### Dados sem pré-processamento.

# %%
# Dados de treino e validação com aumentação:
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
        directory=train_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        shuffle=True)

validation_generator = train_datagen.flow_from_directory(
        directory=val_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        shuffle=False)

batch_X_train, batch_Y_train = train_generator.next()


# Calcula os pesos:
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(train_generator.labels), y=train_generator.labels)
train_class_weights = dict(enumerate(class_weights))
print('train_class_weights: ', train_class_weights)
# Out:
# Found 6548 images belonging to 2 classes.
# Found 2200 images belonging to 2 classes.
# train_class_weights:  {0: 1.2175529936779472, 1: 0.8484063228815756}

# %% [markdown]
# ##### Dados com pré-processamento para resnet50.

# %%
# Dados de treino e validação com aumentação:
train_datagen_resnet = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

train_generator_resnet = train_datagen_resnet.flow_from_directory(
        directory=train_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        shuffle=True)

validation_generator_resnet = train_datagen_resnet.flow_from_directory(
        directory=val_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        shuffle=False)

batch_X_train_resnet, batch_Y_train_resnet = train_generator_resnet.next()

print(batch_X_train_resnet.shape, batch_Y_train_resnet.shape)
# Out:
# Found 6548 images belonging to 2 classes.
# Found 2200 images belonging to 2 classes.
# (32, 224, 224, 3) (32, 2)

# %%
#print("Imagens sem aumentações"), plotImages(batch_X_sa[:10], 1, 10)
print("Imagens sem aumentações + pré-processamento resnet"), plotImages(batch_X_train_resnet[:10], 1, 10)
# Out:
# Imagens sem aumentações + pré-processamento resnet
# (None, None)

# %% [markdown]
# ## Modelo Baseline com ResNet50

# %% [markdown]
# ####Gerando o modelo.

# %%
# Carregamento do modelo pré-treinado SEM as camadas densas (include_top = False)
model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))

# Congela camadas pré-treinadas
for layer in model.layers:
    layer.trainable = False

# Insere novas camadas no fim da rede para classificação
modelB = tf.keras.Sequential([
  model,
  tf.keras.layers.GlobalAveragePooling2D(),
  tf.keras.layers.Dense(256, activation = 'relu'),
  tf.keras.layers.Dense(128, activation = 'relu'),
  tf.keras.layers.Dense(2, activation='softmax')
])

modelB.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 256)               524544
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 24,145,410
# Trainable params: 557,698
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# ####Treinando e avaliando o modelo usando dados com aumentação.

# %%
# Instancia um otimizador SGD, compila e treina o modelo completo
sgd = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, decay=0.001, nesterov=True)

modelB.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy',tf.keras.metrics.AUC()])

history_modelB = modelB.fit(train_generator_resnet, epochs=50,
                  validation_data=validation_generator_resnet, class_weight=train_class_weights)
# Out:
# Epoch 1/50
# 205/205 [==============================] - 597s 3s/step - loss: 0.4587 - accuracy: 0.7851 - auc_1: 0.8683 - val_loss: 0.4123 - val_accuracy: 0.8109 - val_auc_1: 0.8928
# Epoch 2/50
# 205/205 [==============================] - 222s 1s/step - loss: 0.3986 - accuracy: 0.8222 - auc_1: 0.9032 - val_loss: 0.4107 - val_accuracy: 0.8168 - val_auc_1: 0.8942
# Epoch 3/50
# 205/205 [==============================] - 301s 1s/step - loss: 0.3742 - accuracy: 0.8348 - auc_1: 0.9151 - val_loss: 0.3616 - val_accuracy: 0.8450 - val_auc_1: 0.9191
# Epoch 4/50
# 205/205 [==============================] - 291s 1s/step - loss: 0.3639 - accuracy: 0.8424 - auc_1: 0.9205 - val_loss: 0.3667 - val_accuracy: 0.8427 - val_auc_1: 0.9169
# Epoch 5/50
# 205/205 [==============================] - 290s 1s/step - loss: 0.3508 - accuracy: 0.8493 - auc_1: 0.9258 - val_loss: 0.3490 - val_accuracy: 0.8459 - val_auc_1: 0.9246
# Epoch 6/50
# 205/205 [==============================] - 284s 1s/step - loss: 0.3420 - accuracy: 0.8554 - auc_1: 0.9299 - val_loss: 0.3640 - val_accuracy: 0.8409 - val_auc_1: 0.9178
# Epoch 7/50
# 205/205 [==============================] - 286s 1s/step - loss: 0.3395 - accuracy: 0.8555 - auc_1: 0.9311 - val_loss: 0.4086 - val_accuracy: 0.8209 - val_auc_1: 0.8970
# Epoch 8/50
# 205/205 [==============================] - 285s 1s/step - loss: 0.3338 - accuracy: 0.8528 - auc_1: 0.9328 - val_loss: 0.3507 - val_accuracy: 0.8509 - val_auc_1: 0.9242
# Epoch 9/50
# 205/205 [==============================] - 285s 1s/step - loss: 0.3236 - accuracy: 0.8621 - auc_1: 0.9374 - val_loss: 0.3561 - val_accuracy: 0.8432 - val_auc_1: 0.9222
# Epoch 10/50
# 205/205 [==============================] - 286s 1s/step - loss: 0.3248 - accuracy: 0.8613 - auc_1: 0.9372 - val_loss: 0.3391 - val_accuracy: 0.8573 - val_auc_1: 0.9294
# Epoch 11/50
# 205/205 [==============================] - 286s 1s/step - loss: 0.3221 - accuracy: 0.8671 - auc_1: 0.9380 - val_loss: 0.3533 - val_accuracy: 0.8450 - val_auc_1: 0.9230
# Epoch 12/50
# 205/205 [==============================] - 283s 1s/step - loss: 0.3200 - accuracy: 0.8688 - auc_1: 0.9391 - val_loss: 0.3470 - val_accuracy: 0.8564 - val_auc_1: 0.9260
# Epoch 13/50
# 205/205 [==============================] - 280s 1s/step - loss: 0.3157 - accuracy: 0.8661 - auc_1: 0.9409 - val_loss: 0.3395 - val_accuracy: 0.8550 - val_auc_1: 0.9296
# Epoch 14/50
# 205/205 [==============================] - 280s 1s/step - loss: 0.3091 - accuracy: 0.8723 - auc_1: 0.9438 - val_loss: 0.3520 - val_accuracy: 0.8464 - val_auc_1: 0.9234
# Epoch 15/50
# 205/205 [==============================] - 283s 1s/step - loss: 0.3077 - accuracy: 0.8752 - auc_1: 0.9437 - val_loss: 0.3296 - val_accuracy: 0.8595 - val_auc_1: 0.9331
# Epoch 16/50
# 205/205 [==============================] - 281s 1s/step - loss: 0.3065 - accuracy: 0.8737 - auc_1: 0.9445 - val_loss: 0.3364 - val_accuracy: 0.8564 - val_auc_1: 0.9302
# Epoch 17/50
# 205/205 [==============================] - 280s 1s/step - loss: 0.3019 - accuracy: 0.8743 - auc_1: 0.9463 - val_loss: 0.3327 - val_accuracy: 0.8591 - val_auc_1: 0.9318
# Epoch 18/50
# 205/205 [==============================] - 279s 1s/step - loss: 0.3018 - accuracy: 0.8714 - auc_1: 0.9464 - val_loss: 0.3478 - val_accuracy: 0.8541 - val_auc_1: 0.9256
# Epoch 19/50
# 205/205 [==============================] - 279s 1s/step - loss: 0.3028 - accuracy: 0.8703 - auc_1: 0.9459 - val_loss: 0.3467 - val_accuracy: 0.8455 - val_auc_1: 0.9258
# Epoch 20/50
# 205/205 [==============================] - 281s 1s/step - loss: 0.2940 - accuracy: 0.8786 - auc_1: 0.9493 - val_loss: 0.3333 - val_accuracy: 0.8509 - val_auc_1: 0.9319
# Epoch 21/50
# 205/205 [==============================] - 278s 1s/step - loss: 0.2915 - accuracy: 0.8813 - auc_1: 0.9500 - val_loss: 0.3307 - val_accuracy: 0.8577 - val_auc_1: 0.9331
# Epoch 22/50
# 205/205 [==============================] - 280s 1s/step - loss: 0.2958 - accuracy: 0.8792 - auc_1: 0.9482 - val_loss: 0.3384 - val_accuracy: 0.8564 - val_auc_1: 0.9298
# Epoch 23/50
# 205/205 [==============================] - 277s 1s/step - loss: 0.2921 - accuracy: 0.8794 - auc_1: 0.9498 - val_loss: 0.3677 - val_accuracy: 0.8355 - val_auc_1: 0.9171
# Epoch 24/50
# 205/205 [==============================] - 287s 1s/step - loss: 0.2879 - accuracy: 0.8783 - auc_1: 0.9513 - val_loss: 0.3489 - val_accuracy: 0.8573 - val_auc_1: 0.9252
# Epoch 25/50
# 205/205 [==============================] - 281s 1s/step - loss: 0.2845 - accuracy: 0.8855 - auc_1: 0.9526 - val_loss: 0.3434 - val_accuracy: 0.8500 - val_auc_1: 0.9283
# Epoch 26/50
# 205/205 [==============================] - 278s 1s/step - loss: 0.2887 - accuracy: 0.8797 - auc_1: 0.9508 - val_loss: 0.3320 - val_accuracy: 0.8582 - val_auc_1: 0.9321
# Epoch 27/50
# 205/205 [==============================] - 279s 1s/step - loss: 0.2807 - accuracy: 0.8841 - auc_1: 0.9541 - val_loss: 0.3437 - val_accuracy: 0.8564 - val_auc_1: 0.9280
# Epoch 28/50
# 205/205 [==============================] - 283s 1s/step - loss: 0.2778 - accuracy: 0.8859 - auc_1: 0.9552 - val_loss: 0.3460 - val_accuracy: 0.8591 - val_auc_1: 0.9268
# Epoch 29/50
# 205/205 [==============================] - 279s 1s/step - loss: 0.2790 - accuracy: 0.8871 - auc_1: 0.9546 - val_loss: 0.3399 - val_accuracy: 0.8527 - val_auc_1: 0.9297
# Epoch 30/50
# 205/205 [==============================] - 279s 1s/step - loss: 0.2771 - accuracy: 0.8868 - auc_1: 0.9549 - val_loss: 0.3339 - val_accuracy: 0.8564 - val_auc_1: 0.9316
# Epoch 31/50
# 205/205 [==============================] - 279s 1s/step - loss: 0.2807 - accuracy: 0.8868 - auc_1: 0.9536 - val_loss: 0.3458 - val_accuracy: 0.8491 - val_auc_1: 0.9270
# Epoch 32/50
# 205/205 [==============================] - 278s 1s/step - loss: 0.2769 - accuracy: 0.8882 - auc_1: 0.9555 - val_loss: 0.3462 - val_accuracy: 0.8536 - val_auc_1: 0.9271
# Epoch 33/50
# 205/205 [==============================] - 279s 1s/step - loss: 0.2763 - accuracy: 0.8865 - auc_1: 0.9553 - val_loss: 0.3424 - val_accuracy: 0.8518 - val_auc_1: 0.9288
# Epoch 34/50
# 205/205 [==============================] - 283s 1s/step - loss: 0.2769 - accuracy: 0.8890 - auc_1: 0.9551 - val_loss: 0.3511 - val_accuracy: 0.8518 - val_auc_1: 0.9252
# Epoch 35/50
# 205/205 [==============================] - 280s 1s/step - loss: 0.2724 - accuracy: 0.8926 - auc_1: 0.9565 - val_loss: 0.3483 - val_accuracy: 0.8500 - val_auc_1: 0.9259
# Epoch 36/50
# 205/205 [==============================] - 244s 1s/step - loss: 0.2720 - accuracy: 0.8907 - auc_1: 0.9568 - val_loss: 0.3303 - val_accuracy: 0.8605 - val_auc_1: 0.9330
# Epoch 37/50
# 205/205 [==============================] - 226s 1s/step - loss: 0.2721 - accuracy: 0.8896 - auc_1: 0.9568 - val_loss: 0.3362 - val_accuracy: 0.8532 - val_auc_1: 0.9306
# Epoch 38/50
# 205/205 [==============================] - 213s 1s/step - loss: 0.2702 - accuracy: 0.8928 - auc_1: 0.9573 - val_loss: 0.3637 - val_accuracy: 0.8391 - val_auc_1: 0.9193
# Epoch 39/50
# 205/205 [==============================] - 213s 1s/step - loss: 0.2729 - accuracy: 0.8847 - auc_1: 0.9564 - val_loss: 0.3376 - val_accuracy: 0.8505 - val_auc_1: 0.9306
# Epoch 40/50
# 205/205 [==============================] - 211s 1s/step - loss: 0.2664 - accuracy: 0.8919 - auc_1: 0.9592 - val_loss: 0.3483 - val_accuracy: 0.8500 - val_auc_1: 0.9264
# Epoch 41/50
# 205/205 [==============================] - 211s 1s/step - loss: 0.2704 - accuracy: 0.8891 - auc_1: 0.9574 - val_loss: 0.3378 - val_accuracy: 0.8582 - val_auc_1: 0.9303
# Epoch 42/50
# 205/205 [==============================] - 212s 1s/step - loss: 0.2639 - accuracy: 0.8929 - auc_1: 0.9595 - val_loss: 0.3352 - val_accuracy: 0.8577 - val_auc_1: 0.9319
# Epoch 43/50
# 205/205 [==============================] - 209s 1s/step - loss: 0.2600 - accuracy: 0.8951 - auc_1: 0.9613 - val_loss: 0.3310 - val_accuracy: 0.8541 - val_auc_1: 0.9333
# Epoch 44/50
# 205/205 [==============================] - 207s 1s/step - loss: 0.2606 - accuracy: 0.8936 - auc_1: 0.9608 - val_loss: 0.3401 - val_accuracy: 0.8605 - val_auc_1: 0.9300
# Epoch 45/50
# 205/205 [==============================] - 208s 1s/step - loss: 0.2588 - accuracy: 0.8942 - auc_1: 0.9613 - val_loss: 0.3333 - val_accuracy: 0.8545 - val_auc_1: 0.9322
# Epoch 46/50
# 205/205 [==============================] - 207s 1s/step - loss: 0.2603 - accuracy: 0.8931 - auc_1: 0.9607 - val_loss: 0.3502 - val_accuracy: 0.8491 - val_auc_1: 0.9252
# Epoch 47/50
# 205/205 [==============================] - 222s 1s/step - loss: 0.2579 - accuracy: 0.8942 - auc_1: 0.9618 - val_loss: 0.3438 - val_accuracy: 0.8505 - val_auc_1: 0.9287
# Epoch 48/50
# 205/205 [==============================] - 212s 1s/step - loss: 0.2612 - accuracy: 0.8925 - auc_1: 0.9604 - val_loss: 0.3269 - val_accuracy: 0.8555 - val_auc_1: 0.9348
# Epoch 49/50
# 205/205 [==============================] - 208s 1s/step - loss: 0.2563 - accuracy: 0.8951 - auc_1: 0.9621 - val_loss: 0.3434 - val_accuracy: 0.8509 - val_auc_1: 0.9294
# Epoch 50/50
# 205/205 [==============================] - 224s 1s/step - loss: 0.2580 - accuracy: 0.8948 - auc_1: 0.9615 - val_loss: 0.3605 - val_accuracy: 0.8364 - val_auc_1: 0.9216

# %%
history_modelB.history['val_accuracy']
# Out:
# [0.8109090924263,
#  0.8168181777000427,
#  0.8450000286102295,
#  0.8427272439002991,
#  0.8459091186523438,
#  0.8409090638160706,
#  0.8209090828895569,
#  0.8509091138839722,
#  0.8431817889213562,
#  0.857272744178772,
#  0.8450000286102295,
#  0.8563636541366577,
#  0.8550000190734863,
#  0.8463636636734009,
#  0.8595454692840576,
#  0.8563636541366577,
#  0.8590909242630005,
#  0.8540909290313721,
#  0.8454545736312866,
#  0.8509091138839722,
#  0.8577272891998291,
#  0.8563636541366577,
#  0.835454523563385,
#  0.857272744178772,
#  0.8500000238418579,
#  0.8581818342208862,
#  0.8563636541366577,
#  0.8590909242630005,
#  0.8527272939682007,
#  0.8563636541366577,
#  0.8490909337997437,
#  0.8536363840103149,
#  0.8518182039260864,
#  0.8518182039260864,
#  0.8500000238418579,
#  0.8604545593261719,
#  0.8531818389892578,
#  0.839090883731842,
#  0.850454568862915,
#  0.8500000238418579,
#  0.8581818342208862,
#  0.8577272891998291,
#  0.8540909290313721,
#  0.8604545593261719,
#  0.8545454740524292,
#  0.8490909337997437,
#  0.850454568862915,
#  0.8554545640945435,
#  0.8509091138839722,
#  0.8363636136054993]

# %% [markdown]
# ####Salva e importa modelo baseline.

# %%
# Salvando o modelo

import h5py
# save model and architecture to single file
modelB.save("/content/gdrive/MyDrive/Mineracao de Dados Complexos/INF 0619-010 - Trabalho Final - Zanoni/Modelos/modelB_2camadas.h5")
print("Saved model to disk")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Saved model to disk

# %%
#Carrega pesos salvos.
# from keras.models import load_model
# modelB = load_model("/content/gdrive/MyDrive/Mineracao de Dados Complexos/INF 0619-010 - Trabalho Final - Zanoni/Modelos/modelB_2camadas.h5")
# print("Loaded model from disk")

# %% [markdown]
# ####Acurácia balanceada com dados com aumentação.

# %%
#Reseta o gerador para gerar os dados usados no nosso predict.
validation_generator_resnet.reset()

# %%
#Faz a predição à partir dos dados do nosso gerador utilizando o modelo baseline.
y_pred = modelB.predict(validation_generator_resnet)

# %%
# Converte os valores preditos para números inteiros nos valores de 0 ou 1.
y_pred_int = (y_pred > 0.5).astype(np.int32)

# %%
# A lista acima é formada por listas de tamanho 2 onde nos interessa apenas o segundo item de cada lista, portanto o que fazemos nesse trecho é gerar 
# uma nova lista de inteiros selecionando apenas o 2º item de cada lista presente no y_pred_nn.
y_pred_nn = []
for item in y_pred_int:
    y_pred_nn.append(item[1])

# %%
# Novamente faz o reset do gerador para puxarmos os dados do target.
validation_generator_resnet.reset()

# %%
# Gera uma lista com os rótulos de cada imagem.
Y_resnet_val = []

while True:
    x,y = validation_generator_resnet.next()
    
    new_list = []
    for item in y:
        new_list.append(item)
        
    Y_resnet_val += new_list
    if len(Y_resnet_val) > 2200:
        break

# %%
# Acurácia balanceada.
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(validation_generator_resnet.labels, y_pred_nn, sample_weight=None, adjusted=False)
# Out:
# 0.8445504503974797

# %% [markdown]
# ####Resultados do modelo baseline usando dados com aumentação.

# %%
plt.plot(history_modelB.history['loss'], label='loss')
plt.plot(history_modelB.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower left')

#test_loss, test_acc = modelB.evaluate(batch_val_X_proc, batch_val_Y_proc, verbose=2)

# %%
plt.plot(history_modelB.history['accuracy'], label='accuracy')
plt.plot(history_modelB.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend(loc='lower left')

#test_loss, test_acc = frozen_model.evaluate(batch_val_X_proc, batch_val_Y_proc, verbose=2)

# %%
# Matriz de confusão.
import seaborn as sns
from sklearn.metrics import confusion_matrix
np.set_printoptions(precision=4,suppress=True)

# Matriz de confusão
cm = confusion_matrix(validation_generator_resnet.classes, y_pred_nn)

# %%
# Matriz de confusão normalizada
num_classes=2
categories = ['Imagem Empresa', 'Imagem Não Empresa']
cmn = cm / cm.astype(np.float).sum(axis=1, keepdims=True)
balanced_acc = np.trace(cmn) / num_classes
print("\n\nAcurácia balanceada:", balanced_acc)

print("\n\nMatriz de confusão balanceada")
plt.figure(figsize = (11,9))
sns.set(font_scale=0.9)
sns.heatmap(cmn, annot=True, fmt='.1%', xticklabels=categories, yticklabels=categories, cmap = 'Greens')
# Out:
# Acurácia balanceada: 0.8445504503974797
#
#
# Matriz de confusão balanceada

# %% [markdown]
# ####AUC ROC

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresh = roc_curve(validation_generator.classes, y_pred[:,1], pos_label=1)

from sklearn.metrics import roc_auc_score
auc_score = roc_auc_score(validation_generator.classes, y_pred[:,1])
print(auc_score)
# Out:
# 0.9243062958503441

# %%
plt.figure(figsize = (9,7))
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve (area = %0.2f)" % auc_score,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating Curve")
plt.legend(loc="lower right")
plt.show()
